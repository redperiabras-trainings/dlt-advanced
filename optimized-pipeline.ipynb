# %% [markdown]
# # **Homework: Speed up your pipeline**
#
# ### **Goal**
#
# Use the public **Jaffle Shop API** to build a `dlt` pipeline and apply everything you've learned about performance:
#
# - Chunking
# - Parallelism
# - Buffer control
# - File rotation
# - Worker tuning
#
# Your task is to **make the pipeline as fast as possible**, while keeping the results correct.
#
#
#
# ### **What you’ll need**
#
# - API base: `https://jaffle-shop.scalevector.ai/api/v1`
# - Docs: [https://jaffle-shop.scalevector.ai/docs](https://jaffle-shop.scalevector.ai/docs)
# - Start with these endpoints:
#   - `/customers`
#   - `/orders`
#   - `/products`
#
# Each of them returns **paged responses** — so you'll need to handle pagination.
#
#
#
# ### **What to implement**
#
# 1. **Extract** from the API using `dlt`
#    - Use `dlt.resource` and [`RESTClient`](https://dlthub.com/docs/devel/general-usage/http/rest-client) with proper pagination
#
# 2. **Apply all performance techniques**
#    - Group resources into sources
#    - Yield **chunks/pages**, not single rows
#    - Use `parallelized=True`
#    - Set `EXTRACT__WORKERS`, `NORMALIZE__WORKERS`, and `LOAD__WORKERS`
#    - Tune buffer sizes and enable **file rotation**
#
# 3. **Measure performance**
#    - Time the extract, normalize, and load stages separately
#    - Compare a naive version vs. optimized version
#    - Log thread info or `pipeline.last_trace` if helpful
#
#
# ### **Deliverables**
#
# Share your code as a Google Colab or [GitHub Gist](https://gist.github.com/) in Homework Google Form. **This step is required for certification.**
#
#
# It should include:
# - Working pipeline for at least 2 endpoints
# - Before/after timing comparison
# - A short explanation of what changes made the biggest difference if there're any differences

# %%
import dlt
import os

from dlt.sources.helpers.rest_client import RESTClient
from dlt.sources.helpers.rest_client.paginators import PageNumberPaginator

# %%
os.environ["EXTRACT__WORKERS"] = "3"

# %%
base_url = 'https://jaffle-shop.scalevector.ai/api/v1'
page_size = 1_000

# %%
@dlt.source(name='jaffle_shop')
def jaffle_shop_source():

    client = RESTClient(
        base_url=base_url, 
        paginator=PageNumberPaginator(
            page_param='page',
            base_page=1,
            total_path=None
        )
    )

    @dlt.resource(name="customers", primary_key="id", parallelized=True)
    def get_customers():
        for page in client.paginate("customers"):
            yield page

    @dlt.resource(name="products", primary_key="sku", parallelized=True)
    def get_products():
        for page in client.paginate("products"):
            yield page

    @dlt.resource(name="orders", primary_key="id", parallelized=True)
    def get_orders():
        for page in client.paginate("orders", params={"page_size": page_size}):
            yield page

    return [get_customers, get_orders, get_products]

# %%
pipeline = dlt.pipeline(
    destination='duckdb',
    dataset_name='optimized-jaffle_shop',
    full_refresh=True,
    progress='log'
)
# Out:
# /Users/redperiabras/Developer/dlt-advanced/.venv/lib/python3.10/site-packages/dlt/pipeline/__init__.py:133: Dlt04DeprecationWarning: The `full_refresh` argument to pipeline is deprecated and will be removed in a future version. Use `dev_mode=True` instead which will have the same effect. Deprecated in dlt 0.4.0 to be removed in 1.0.0.
#   full_refresh_argument_deprecated("pipeline", full_refresh)

# %%
# %timeit

pipeline.extract(jaffle_shop_source())
# Out:
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources:
) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 890.76s | Rate: 0.00/s
# products: 10  | Time: 887.86s | Rate: 0.01/s
# customers: 935  | Time: 887.82s | Rate: 1.05/s
# orders: 61948  | Time: 877.80s | Rate: 70.57/s
# Memory usage: 47.59 MB (83.80%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 3/3 (100.0%) | Time: 890.85s | Rate: 0.00/s
# products: 10  | Time: 887.95s | Rate: 0.01/s
# customers: 935  | Time: 887.91s | Rate: 1.05/s
# orders: 61948  | Time: 877.89s | Rate: 70.56/s
# Memory usage: 55.19 MB (83.70%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 0/1 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Memory usage: 60.86 MB (83.70%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 0/1 (0.0%) | Time: 0.00s | Rate: 0.00/s
# _dlt_pipeline_state: 1  | Time: 0.00s | Rate: 838860.80/s
# Memory usage: 61.16 MB (83.70%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 1/1 (100.0%) | Time: 0.02s | Rate: 59.64/s
# _dlt_pipeline_state: 1  | Time: 0.01s | Rate: 69.83/s
# Memory usage: 61.95 MB (83.70%) | CPU usage: 0.00%
# ExtractInfo(pipeline=<dlt.pipeline.pipeline.Pipeline object at 0x10a9241c0>, metrics={'1748260293.5200179': [{'started_at': DateTime(2025, 5, 26, 11, 51, 33, 525768, tzinfo=Timezone('UTC')), 'finished_at': DateTime(2025, 5, 26, 12, 6, 24, 378966, tzinfo=Timezone('UTC')), 'schema_name': 'jaffle_shop', 'job_metrics': {'products.b2810c038d.typed-jsonl': DataWriterMetrics(file_path='/Users/redperiabras/.dlt/pipelines/dlt_ipykernel_launcher/normalize/864818dd52e7deb6/1748260293.5200179/new_jobs/products.b2810c038d.0.typed-jsonl', items_count=10, file_size=1416, created=1748260296.4261482, last_modified=1748260307.907465), 'customers.d2386d29ef.typed-jsonl': DataWriterMetrics(file_path='/Users/redperiabras/.dlt/pipelines/dlt_ipykernel_launcher/normalize/864818dd52e7deb6/1748260293.5200179/new_jobs/customers.d2386d29ef.0.typed-jsonl', items_count=935, file_size=64816, created=1748260296.4731278, last_modified=1748260334.629886), 'orders.b7253007de.typed-jsonl': DataWriterMetrics(file_path='/Users/redperiabras/.dlt/pipelines/dlt_ipykernel_launcher/normalize/864818dd52e7deb6/1748260293.5200179/new_jobs/orders.b7253007de.0.typed-jsonl', items_count=61948, file_size=25523121, created=1748260306.485875, last_modified=1748261184.290435)}, 'table_metrics': {'products': DataWriterMetrics(file_path='', items_count=10, file_size=1416, created=1748260296.4261482, last_modified=1748260307.907465), 'customers': DataWriterMetrics(file_path='', items_count=935, file_size=64816, created=1748260296.4731278, last_modified=1748260334.629886), 'orders': DataWriterMetrics(file_path='', items_count=61948, file_size=25523121, created=1748260306.485875, last_modified=1748261184.290435)}, 'resource_metrics': {'products': DataWriterMetrics(file_path='', items_count=10, file_size=1416, created=1748260296.4261482, last_modified=1748260307.907465), 'customers': DataWriterMetrics(file_path='', items_count=935, file_size=64816, created=1748260296.4731278, last_modified=1748260334.629886), 'orders': DataWriterMetrics(file_path='', items_count=61948, file_size=25523121, created=1748260306.485875, last_modified=1748261184.290435)}, 'dag': [('customers', 'customers'), ('orders', 'orders'), ('products', 'products')], 'hints': {'customers': {'write_disposition': 'append', 'primary_key': 'id'}, 'orders': {'write_disposition': 'append', 'primary_key': 'id'}, 'products': {'write_disposition': 'append', 'primary_key': 'sku'}}}, {'started_at': DateTime(2025, 5, 26, 12, 6, 24, 389207, tzinfo=Timezone('UTC')), 'finished_at': DateTime(2025, 5, 26, 12, 6, 24, 406353, tzinfo=Timezone('UTC')), 'schema_name': 'jaffle_shop', 'job_metrics': {'_dlt_pipeline_state.25af1b6455.typed-jsonl': DataWriterMetrics(file_path='/Users/redperiabras/.dlt/pipelines/dlt_ipykernel_launcher/normalize/864818dd52e7deb6/1748260293.5200179/new_jobs/_dlt_pipeline_state.25af1b6455.0.typed-jsonl', items_count=1, file_size=540, created=1748261184.392043, last_modified=1748261184.3920472)}, 'table_metrics': {'_dlt_pipeline_state': DataWriterMetrics(file_path='', items_count=1, file_size=540, created=1748261184.392043, last_modified=1748261184.3920472)}, 'resource_metrics': {'_dlt_pipeline_state': DataWriterMetrics(file_path='', items_count=1, file_size=540, created=1748261184.392043, last_modified=1748261184.3920472)}, 'dag': [('_dlt_pipeline_state', '_dlt_pipeline_state')], 'hints': {'_dlt_pipeline_state': {'columns': 'version:\n  name: version\n  data_type: bigint\n  nullable: false\nengine_version:\n  name: engine_version\n  data_type: bigint\n  nullable: false\npipeline_name:\n  name: pipeline_name\n  data_type: text\n  nullable: false\nstate:\n  name: state\n  data_type: text\n  nullable: false\ncreated_at:\n  name: created_at\n  data_type: timestamp\n  nullable: false\nversion_hash:\n  name: version_hash\n  data_type: text\n  nullable: true\n_dlt_load_id:\n  name: _dlt_load_id\n  data_type: text\n  nullable: false\n', 'write_disposition': 'append', 'file_format': 'preferred', 'original_columns': 'dict'}}} ...

# %%
# %%timeit

pipeline.normalize()
# Out:
# ----------------- Normalize jaffle_shop in 1748260293.5200179 ------------------
# Files: 0/4 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Memory usage: 49.28 MB (86.30%) | CPU usage: 0.00%
#
# ----------------- Normalize jaffle_shop in 1748260293.5200179 ------------------
# Files: 0/4 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Items: 0  | Time: 0.00s | Rate: 0.00/s
# Memory usage: 49.45 MB (86.30%) | CPU usage: 0.00%
#
# ----------------- Normalize jaffle_shop in 1748260293.5200179 ------------------
# Files: 5/4 (125.0%) | Time: 5.20s | Rate: 0.96/s
# Items: 0  | Time: 5.20s | Rate: 0.00/s
# Memory usage: 186.28 MB (86.10%) | CPU usage: 0.00%
#
# ----------------- Normalize jaffle_shop in 1748260293.5200179 ------------------
# Files: 5/4 (125.0%) | Time: 5.21s | Rate: 0.96/s
# Items: 153794  | Time: 5.21s | Rate: 29531.72/s
# Memory usage: 191.12 MB (86.00%) | CPU usage: 0.00%
#
# 8.52 ms ± 1.09 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit

load_info = pipeline.load()
# Out:
# 2025-05-26 20:42:11,629|[WARNING]|59736|8716787456|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131' to 'optimized_jaffle_shop_20250526115131 which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:11,629|[WARNING]|59736|8716787456|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131_staging' to 'optimized_jaffle_shop_20250526115131_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:11,635|[WARNING]|59736|8716787456|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131' to 'optimized_jaffle_shop_20250526115131 which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:11,635|[WARNING]|59736|8716787456|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131_staging' to 'optimized_jaffle_shop_20250526115131_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:11,740|[WARNING]|59736|8716787456|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131' to 'optimized_jaffle_shop_20250526115131 which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:11,741|[WARNING]|59736|8716787456|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131_staging' to 'optimized_jaffle_shop_20250526115131_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:11,742|[WARNING]|59736|6293516288|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131' to 'optimized_jaffle_shop_20250526115131 which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:11,743|[WARNING]|59736|8716787456|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131' to 'optimized_jaffle_shop_20250526115131 which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:11,743|[WARNING]|59736|6293516288|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131_staging' to 'optimized_jaffle_shop_20250526115131_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:11,743|[WARNING]|59736|8716787456|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131_staging' to 'optimized_jaffle_shop_20250526115131_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:11,744|[WARNING]|59736|6310342656|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131' to 'optimized_jaffle_shop_20250526115131 which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:11,744|[WARNING]|59736|8716787456|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131' to 'optimized_jaffle_shop_20250526115131 which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:11,745|[WARNING]|59736|6310342656|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131_staging' to 'optimized_jaffle_shop_20250526115131_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:11,745|[WARNING]|59736|8716787456|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131_staging' to 'optimized_jaffle_shop_20250526115131_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:11,746|[WARNING]|59736|6327169024|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131' to 'optimized_jaffle_shop_20250526115131 which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:11,747|[WARNING]|59736|8716787456|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131' to 'optimized_jaffle_shop_20250526115131 which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:11,747|[WARNING]|59736|6327169024|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131_staging' to 'optimized_jaffle_shop_20250526115131_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:11,747|[WARNING]|59736|8716787456|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131_staging' to 'optimized_jaffle_shop_20250526115131_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:11,748|[WARNING]|59736|6348009472|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131' to 'optimized_jaffle_shop_20250526115131 which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:11,748|[WARNING]|59736|8716787456|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131' to 'optimized_jaffle_shop_20250526115131 which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:11,749|[WARNING]|59736|6348009472|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131_staging' to 'optimized_jaffle_shop_20250526115131_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:11,749|[WARNING]|59736|8716787456|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131_staging' to 'optimized_jaffle_shop_20250526115131_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:11,750|[WARNING]|59736|6364835840|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131' to 'optimized_jaffle_shop_20250526115131 which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:11,750|[WARNING]|59736|6364835840|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131_staging' to 'optimized_jaffle_shop_20250526115131_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:11,755|[WARNING]|59736|8716787456|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131' to 'optimized_jaffle_shop_20250526115131 which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:11,757|[WARNING]|59736|8716787456|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131_staging' to 'optimized_jaffle_shop_20250526115131_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:11,760|[WARNING]|59736|8716787456|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131' to 'optimized_jaffle_shop_20250526115131 which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:11,762|[WARNING]|59736|8716787456|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131_staging' to 'optimized_jaffle_shop_20250526115131_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:11,780|[WARNING]|59736|8716787456|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131' to 'optimized_jaffle_shop_20250526115131 which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:11,780|[WARNING]|59736|8716787456|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131_staging' to 'optimized_jaffle_shop_20250526115131_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# -------------------- Load jaffle_shop in 1748260293.5200179 --------------------
# Jobs: 0/5 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Memory usage: 156.14 MB (85.10%) | CPU usage: 0.00%
# 2025-05-26 20:42:17,454|[WARNING]|59736|8716787456|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131' to 'optimized_jaffle_shop_20250526115131 which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:17,456|[WARNING]|59736|8716787456|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131_staging' to 'optimized_jaffle_shop_20250526115131_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# -------------------- Load jaffle_shop in 1748260293.5200179 --------------------
# Jobs: 3/5 (60.0%) | Time: 5.82s | Rate: 0.52/s
# Memory usage: 629.62 MB (84.70%) | CPU usage: 0.00%
# 2025-05-26 20:42:17,722|[WARNING]|59736|8716787456|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131' to 'optimized_jaffle_shop_20250526115131 which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:17,722|[WARNING]|59736|8716787456|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131_staging' to 'optimized_jaffle_shop_20250526115131_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:17,724|[WARNING]|59736|8716787456|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131' to 'optimized_jaffle_shop_20250526115131 which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:17,724|[WARNING]|59736|8716787456|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131_staging' to 'optimized_jaffle_shop_20250526115131_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:17,931|[WARNING]|59736|8716787456|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131' to 'optimized_jaffle_shop_20250526115131 which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:17,941|[WARNING]|59736|8716787456|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131' to 'optimized_jaffle_shop_20250526115131 which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:17,942|[WARNING]|59736|8716787456|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131_staging' to 'optimized_jaffle_shop_20250526115131_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:17,953|[WARNING]|59736|8716787456|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131' to 'optimized_jaffle_shop_20250526115131 which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:17,953|[WARNING]|59736|8716787456|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131_staging' to 'optimized_jaffle_shop_20250526115131_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:17,963|[WARNING]|59736|8716787456|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131' to 'optimized_jaffle_shop_20250526115131 which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:17,964|[WARNING]|59736|8716787456|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131_staging' to 'optimized_jaffle_shop_20250526115131_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:17,973|[WARNING]|59736|8716787456|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131' to 'optimized_jaffle_shop_20250526115131 which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:17,974|[WARNING]|59736|8716787456|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131_staging' to 'optimized_jaffle_shop_20250526115131_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:17,985|[WARNING]|59736|8716787456|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131' to 'optimized_jaffle_shop_20250526115131 which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:17,986|[WARNING]|59736|8716787456|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131_staging' to 'optimized_jaffle_shop_20250526115131_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:17,995|[WARNING]|59736|8716787456|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131' to 'optimized_jaffle_shop_20250526115131 which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:17,995|[WARNING]|59736|8716787456|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131_staging' to 'optimized_jaffle_shop_20250526115131_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:18,006|[WARNING]|59736|8716787456|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131' to 'optimized_jaffle_shop_20250526115131 which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-05-26 20:42:18,007|[WARNING]|59736|8716787456|dlt|client.py|_normalize_identifier:243|Due to normalization dataset name got changed from 'optimized-jaffle_shop_20250526115131_staging' to 'optimized_jaffle_shop_20250526115131_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# -------------------- Load jaffle_shop in 1748260293.5200179 --------------------
# Jobs: 5/5 (100.0%) | Time: 6.30s | Rate: 0.79/s
# Memory usage: 205.27 MB (80.80%) | CPU usage: 0.00%
#
# 10.6 ms ± 947 μs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
print(pipeline.last_trace)
# Out:
# Run started at 2025-05-26 11:51:33.508046+00:00 and COMPLETED in 50 minutes and 44.50 seconds with 17 steps.
# Step extract COMPLETED in 14 minutes and 50.90 seconds.
#
# Load package 1748260293.5200179 is EXTRACTED and NOT YET LOADED to the destination and contains no failed jobs
#
# Step normalize COMPLETED in 5.25 seconds.
# Normalized data for the following tables:
# - orders: 61948 row(s)
# - orders__items: 90900 row(s)
# - customers: 935 row(s)
# - _dlt_pipeline_state: 1 row(s)
# - products: 10 row(s)
#
# Load package 1748260293.5200179 is NORMALIZED and NOT YET LOADED to the destination and contains no failed jobs
#
# Step normalize COMPLETED in 0.01 seconds.
# No data found to normalize
#
# Step normalize COMPLETED in 0.01 seconds.
# No data found to normalize
#
# Step normalize COMPLETED in 0.01 seconds.
# No data found to normalize
#
# Step normalize COMPLETED in 0.01 seconds.
# No data found to normalize
#
# Step normalize COMPLETED in 0.01 seconds.
# No data found to normalize
#
# Step normalize COMPLETED in 0.01 seconds.
# No data found to normalize
#
# Step normalize COMPLETED in 0.01 seconds.
# No data found to normalize
#
# Step load COMPLETED in 6.33 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in 6.30 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset optimized_jaffle_shop_20250526115131
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
# Load package 1748260293.5200179 is LOADED and contains no failed jobs
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
