# %% [markdown]
# # **Homework: Speed up your pipeline**
#
# ### **Goal**
#
# Use the public **Jaffle Shop API** to build a `dlt` pipeline and apply everything you've learned about performance:
#
# - Chunking
# - Parallelism
# - Buffer control
# - File rotation
# - Worker tuning
#
# Your task is to **make the pipeline as fast as possible**, while keeping the results correct.
#
#
#
# ### **What you’ll need**
#
# - API base: `https://jaffle-shop.scalevector.ai/api/v1`
# - Docs: [https://jaffle-shop.scalevector.ai/docs](https://jaffle-shop.scalevector.ai/docs)
# - Start with these endpoints:
#   - `/customers`
#   - `/orders`
#   - `/products`
#
# Each of them returns **paged responses** — so you'll need to handle pagination.
#
#
#
# ### **What to implement**
#
# 1. **Extract** from the API using `dlt`
#    - Use `dlt.resource` and [`RESTClient`](https://dlthub.com/docs/devel/general-usage/http/rest-client) with proper pagination
#
# 2. **Apply all performance techniques**
#    - Group resources into sources
#    - Yield **chunks/pages**, not single rows
#    - Use `parallelized=True`
#    - Set `EXTRACT__WORKERS`, `NORMALIZE__WORKERS`, and `LOAD__WORKERS`
#    - Tune buffer sizes and enable **file rotation**
#
# 3. **Measure performance**
#    - Time the extract, normalize, and load stages separately
#    - Compare a naive version vs. optimized version
#    - Log thread info or `pipeline.last_trace` if helpful
#
#
# ### **Deliverables**
#
# Share your code as a Google Colab or [GitHub Gist](https://gist.github.com/) in Homework Google Form. **This step is required for certification.**
#
#
# It should include:
# - Working pipeline for at least 2 endpoints
# - Before/after timing comparison
# - A short explanation of what changes made the biggest difference if there're any differences

# %%
import dlt
import time

from dlt.sources.helpers.rest_client import RESTClient
from dlt.sources.helpers.rest_client.paginators import PageNumberPaginator

# %%
os.environ["DATA_WRITER__BUFFER_MAX_ITEMS"] = "5000"

# %%
base_url = 'https://jaffle-shop.scalevector.ai/api/v1'

# %%
@dlt.source(name='jaffle_shop')
def jaffle_shop_source():
    
    client = RESTClient(
        base_url=base_url, 
        paginator=PageNumberPaginator(
            page_param='page',
            base_page=1,
            total_path=None
        )
    )

    @dlt.resource(name='customers')
    def get_customers():
        for page in client.paginate('customers'):
            yield page
            
    @dlt.resource(name='orders')
    def get_orders():
        for page in client.paginate('orders'):
            yield page
    
    @dlt.resource(name='products')
    def get_products():
        for page in client.paginate('products'):
            yield page
    
    return [get_customers(), get_orders(), get_products()]

# %%
pipeline = dlt.pipeline(
    destination='duckdb',
    dataset_name='jaffle_shop',
    full_refresh=True,
    progress='log'
)

# %%
# %timeit

pipeline.extract(jaffle_shop_source())
# Out:
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 0/3 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Memory usage: 51.38 MB (85.90%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 0/3 (0.0%) | Time: 1.07s | Rate: 0.00/s
# customers: 100  | Time: 0.00s | Rate: 32263876.92/s
# Memory usage: 64.98 MB (85.70%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 0/3 (0.0%) | Time: 2.50s | Rate: 0.00/s
# customers: 100  | Time: 1.43s | Rate: 69.88/s
# orders: 100  | Time: 0.00s | Rate: 19065018.18/s
# Memory usage: 66.30 MB (85.30%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 0/3 (0.0%) | Time: 3.47s | Rate: 0.00/s
# customers: 100  | Time: 2.40s | Rate: 41.66/s
# orders: 100  | Time: 0.97s | Rate: 103.16/s
# products: 10  | Time: 0.00s | Rate: 2467237.65/s
# Memory usage: 64.92 MB (85.30%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 0/3 (0.0%) | Time: 5.62s | Rate: 0.00/s
# customers: 200  | Time: 4.55s | Rate: 43.95/s
# orders: 200  | Time: 3.12s | Rate: 64.11/s
# products: 10  | Time: 2.15s | Rate: 4.65/s
# Memory usage: 54.70 MB (85.50%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 0/3 (0.0%) | Time: 7.55s | Rate: 0.00/s
# customers: 300  | Time: 6.48s | Rate: 46.28/s
# orders: 200  | Time: 5.05s | Rate: 39.59/s
# products: 10  | Time: 4.08s | Rate: 2.45/s
# Memory usage: 51.28 MB (85.30%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 0/3 (0.0%) | Time: 8.97s | Rate: 0.00/s
# customers: 300  | Time: 7.91s | Rate: 37.93/s
# orders: 300  | Time: 6.48s | Rate: 46.32/s
# products: 10  | Time: 5.51s | Rate: 1.82/s
# Memory usage: 46.58 MB (85.70%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 1/3 (33.3%) | Time: 11.21s | Rate: 0.09/s
# customers: 400  | Time: 10.14s | Rate: 39.45/s
# orders: 400  | Time: 8.71s | Rate: 45.93/s
# products: 10  | Time: 7.74s | Rate: 1.29/s
# Memory usage: 48.67 MB (85.60%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 1/3 (33.3%) | Time: 13.31s | Rate: 0.08/s
# customers: 500  | Time: 12.24s | Rate: 40.84/s
# orders: 500  | Time: 10.81s | Rate: 46.25/s
# products: 10  | Time: 9.84s | Rate: 1.02/s
# Memory usage: 44.98 MB (85.30%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 1/3 (33.3%) | Time: 15.29s | Rate: 0.07/s
# customers: 600  | Time: 14.22s | Rate: 42.19/s
# orders: 600  | Time: 12.79s | Rate: 46.92/s
# products: 10  | Time: 11.82s | Rate: 0.85/s
# Memory usage: 43.64 MB (85.40%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 1/3 (33.3%) | Time: 17.06s | Rate: 0.06/s
# customers: 700  | Time: 15.99s | Rate: 43.78/s
# orders: 700  | Time: 14.56s | Rate: 48.08/s
# products: 10  | Time: 13.59s | Rate: 0.74/s
# Memory usage: 40.16 MB (84.30%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 1/3 (33.3%) | Time: 18.44s | Rate: 0.05/s
# customers: 800  | Time: 17.37s | Rate: 46.05/s
# orders: 700  | Time: 15.94s | Rate: 43.91/s
# products: 10  | Time: 14.97s | Rate: 0.67/s
# Memory usage: 47.89 MB (84.70%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 1/3 (33.3%) | Time: 19.96s | Rate: 0.05/s
# customers: 800  | Time: 18.89s | Rate: 42.35/s
# orders: 800  | Time: 17.46s | Rate: 45.82/s
# products: 10  | Time: 16.49s | Rate: 0.61/s
# Memory usage: 48.45 MB (85.50%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 1/3 (33.3%) | Time: 21.89s | Rate: 0.05/s
# customers: 900  | Time: 20.82s | Rate: 43.22/s
# orders: 900  | Time: 19.39s | Rate: 46.41/s
# products: 10  | Time: 18.42s | Rate: 0.54/s
# Memory usage: 43.59 MB (85.30%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 1/3 (33.3%) | Time: 23.85s | Rate: 0.04/s
# customers: 935  | Time: 22.79s | Rate: 41.03/s
# orders: 1000  | Time: 21.36s | Rate: 46.82/s
# products: 10  | Time: 20.39s | Rate: 0.49/s
# Memory usage: 48.81 MB (85.60%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 1/3 (33.3%) | Time: 24.98s | Rate: 0.04/s
# customers: 935  | Time: 23.91s | Rate: 39.10/s
# orders: 1000  | Time: 22.48s | Rate: 44.48/s
# products: 10  | Time: 21.51s | Rate: 0.46/s
# Memory usage: 49.06 MB (85.60%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 1/3 (33.3%) | Time: 26.75s | Rate: 0.04/s
# customers: 935  | Time: 25.69s | Rate: 36.40/s
# orders: 1100  | Time: 24.25s | Rate: 45.35/s
# products: 10  | Time: 23.28s | Rate: 0.43/s
# Memory usage: 50.34 MB (85.30%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 28.12s | Rate: 0.07/s
# customers: 935  | Time: 27.05s | Rate: 34.56/s
# orders: 1100  | Time: 25.62s | Rate: 42.93/s
# products: 10  | Time: 24.65s | Rate: 0.41/s
# Memory usage: 40.94 MB (85.60%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 29.50s | Rate: 0.07/s
# customers: 935  | Time: 28.44s | Rate: 32.88/s
# orders: 1300  | Time: 27.00s | Rate: 48.14/s
# products: 10  | Time: 26.04s | Rate: 0.38/s
# Memory usage: 37.19 MB (85.10%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 30.61s | Rate: 0.07/s
# customers: 935  | Time: 29.54s | Rate: 31.65/s
# orders: 1400  | Time: 28.11s | Rate: 49.80/s
# products: 10  | Time: 27.14s | Rate: 0.37/s
# Memory usage: 46.98 MB (84.50%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 31.71s | Rate: 0.06/s
# customers: 935  | Time: 30.64s | Rate: 30.51/s
# orders: 1500  | Time: 29.21s | Rate: 51.35/s
# products: 10  | Time: 28.24s | Rate: 0.35/s
# Memory usage: 48.27 MB (84.40%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 33.28s | Rate: 0.06/s
# customers: 935  | Time: 32.21s | Rate: 29.02/s
# orders: 1600  | Time: 30.78s | Rate: 51.98/s
# products: 10  | Time: 29.81s | Rate: 0.34/s
# Memory usage: 49.22 MB (84.40%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 34.57s | Rate: 0.06/s
# customers: 935  | Time: 33.50s | Rate: 27.91/s
# orders: 1700  | Time: 32.07s | Rate: 53.01/s
# products: 10  | Time: 31.10s | Rate: 0.32/s
# Memory usage: 49.73 MB (84.30%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 36.02s | Rate: 0.06/s
# customers: 935  | Time: 34.95s | Rate: 26.75/s
# orders: 1800  | Time: 33.52s | Rate: 53.70/s
# products: 10  | Time: 32.55s | Rate: 0.31/s
# Memory usage: 50.50 MB (83.90%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 37.09s | Rate: 0.05/s
# customers: 935  | Time: 36.02s | Rate: 25.96/s
# orders: 1900  | Time: 34.59s | Rate: 54.93/s
# products: 10  | Time: 33.62s | Rate: 0.30/s
# Memory usage: 51.30 MB (83.40%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 38.50s | Rate: 0.05/s
# customers: 935  | Time: 37.43s | Rate: 24.98/s
# orders: 2000  | Time: 36.00s | Rate: 55.56/s
# products: 10  | Time: 35.03s | Rate: 0.29/s
# Memory usage: 51.59 MB (83.40%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 39.71s | Rate: 0.05/s
# customers: 935  | Time: 38.64s | Rate: 24.20/s
# orders: 2100  | Time: 37.21s | Rate: 56.43/s
# products: 10  | Time: 36.24s | Rate: 0.28/s
# Memory usage: 52.12 MB (83.30%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 40.89s | Rate: 0.05/s
# customers: 935  | Time: 39.83s | Rate: 23.48/s
# orders: 2200  | Time: 38.40s | Rate: 57.30/s
# products: 10  | Time: 37.43s | Rate: 0.27/s
# Memory usage: 52.77 MB (83.20%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 42.17s | Rate: 0.05/s
# customers: 935  | Time: 41.11s | Rate: 22.74/s
# orders: 2300  | Time: 39.68s | Rate: 57.97/s
# products: 10  | Time: 38.71s | Rate: 0.26/s
# Memory usage: 47.25 MB (83.70%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 43.50s | Rate: 0.05/s
# customers: 935  | Time: 42.43s | Rate: 22.04/s
# orders: 2400  | Time: 41.00s | Rate: 58.54/s
# products: 10  | Time: 40.03s | Rate: 0.25/s
# Memory usage: 47.75 MB (79.80%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 45.18s | Rate: 0.04/s
# customers: 935  | Time: 44.11s | Rate: 21.20/s
# orders: 2500  | Time: 42.68s | Rate: 58.57/s
# products: 10  | Time: 41.71s | Rate: 0.24/s
# Memory usage: 48.69 MB (83.80%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 46.29s | Rate: 0.04/s
# customers: 935  | Time: 45.22s | Rate: 20.68/s
# orders: 2600  | Time: 43.79s | Rate: 59.37/s
# products: 10  | Time: 42.82s | Rate: 0.23/s
# Memory usage: 49.06 MB (83.80%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 47.67s | Rate: 0.04/s
# customers: 935  | Time: 46.60s | Rate: 20.06/s
# orders: 2700  | Time: 45.17s | Rate: 59.78/s
# products: 10  | Time: 44.20s | Rate: 0.23/s
# Memory usage: 49.53 MB (83.90%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 48.91s | Rate: 0.04/s
# customers: 935  | Time: 47.85s | Rate: 19.54/s
# orders: 2800  | Time: 46.42s | Rate: 60.32/s
# products: 10  | Time: 45.45s | Rate: 0.22/s
# Memory usage: 49.72 MB (84.30%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 50.07s | Rate: 0.04/s
# customers: 935  | Time: 49.01s | Rate: 19.08/s
# orders: 2900  | Time: 47.57s | Rate: 60.96/s
# products: 10  | Time: 46.60s | Rate: 0.21/s
# Memory usage: 50.41 MB (83.60%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 51.18s | Rate: 0.04/s
# customers: 935  | Time: 50.11s | Rate: 18.66/s
# orders: 3000  | Time: 48.68s | Rate: 61.62/s
# products: 10  | Time: 47.71s | Rate: 0.21/s
# Memory usage: 51.19 MB (82.80%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 52.33s | Rate: 0.04/s
# customers: 935  | Time: 51.27s | Rate: 18.24/s
# orders: 3100  | Time: 49.83s | Rate: 62.21/s
# products: 10  | Time: 48.87s | Rate: 0.20/s
# Memory usage: 52.14 MB (82.30%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 53.69s | Rate: 0.04/s
# customers: 935  | Time: 52.62s | Rate: 17.77/s
# orders: 3200  | Time: 51.19s | Rate: 62.51/s
# products: 10  | Time: 50.22s | Rate: 0.20/s
# Memory usage: 125.77 MB (84.10%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 54.98s | Rate: 0.04/s
# customers: 935  | Time: 53.92s | Rate: 17.34/s
# orders: 3300  | Time: 52.49s | Rate: 62.87/s
# products: 10  | Time: 51.52s | Rate: 0.19/s
# Memory usage: 38.39 MB (85.60%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 57.01s | Rate: 0.04/s
# customers: 935  | Time: 55.94s | Rate: 16.71/s
# orders: 3400  | Time: 54.51s | Rate: 62.38/s
# products: 10  | Time: 53.54s | Rate: 0.19/s
# Memory usage: 39.19 MB (85.60%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 58.22s | Rate: 0.03/s
# customers: 935  | Time: 57.15s | Rate: 16.36/s
# orders: 3500  | Time: 55.72s | Rate: 62.81/s
# products: 10  | Time: 54.75s | Rate: 0.18/s
# Memory usage: 47.55 MB (85.70%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 59.93s | Rate: 0.03/s
# customers: 935  | Time: 58.86s | Rate: 15.89/s
# orders: 3600  | Time: 57.43s | Rate: 62.69/s
# products: 10  | Time: 56.46s | Rate: 0.18/s
# Memory usage: 46.88 MB (85.70%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 61.05s | Rate: 0.03/s
# customers: 935  | Time: 59.98s | Rate: 15.59/s
# orders: 3700  | Time: 58.55s | Rate: 63.19/s
# products: 10  | Time: 57.58s | Rate: 0.17/s
# Memory usage: 47.42 MB (85.40%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 62.15s | Rate: 0.03/s
# customers: 935  | Time: 61.09s | Rate: 15.31/s
# orders: 3800  | Time: 59.66s | Rate: 63.70/s
# products: 10  | Time: 58.69s | Rate: 0.17/s
# Memory usage: 48.25 MB (85.90%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 63.22s | Rate: 0.03/s
# customers: 935  | Time: 62.15s | Rate: 15.04/s
# orders: 3900  | Time: 60.72s | Rate: 64.23/s
# products: 10  | Time: 59.75s | Rate: 0.17/s
# Memory usage: 49.27 MB (85.50%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 64.32s | Rate: 0.03/s
# customers: 935  | Time: 63.26s | Rate: 14.78/s
# orders: 4000  | Time: 61.83s | Rate: 64.70/s
# products: 10  | Time: 60.86s | Rate: 0.16/s
# Memory usage: 50.20 MB (85.70%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 65.85s | Rate: 0.03/s
# customers: 935  | Time: 64.78s | Rate: 14.43/s
# orders: 4100  | Time: 63.35s | Rate: 64.72/s
# products: 10  | Time: 62.38s | Rate: 0.16/s
# Memory usage: 49.34 MB (85.60%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 67.07s | Rate: 0.03/s
# customers: 935  | Time: 66.01s | Rate: 14.16/s
# orders: 4200  | Time: 64.58s | Rate: 65.04/s
# products: 10  | Time: 63.61s | Rate: 0.16/s
# Memory usage: 47.64 MB (85.30%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 68.51s | Rate: 0.03/s
# customers: 935  | Time: 67.44s | Rate: 13.86/s
# orders: 4300  | Time: 66.01s | Rate: 65.14/s
# products: 10  | Time: 65.04s | Rate: 0.15/s
# Memory usage: 48.39 MB (85.40%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 69.69s | Rate: 0.03/s
# customers: 935  | Time: 68.63s | Rate: 13.62/s
# orders: 4400  | Time: 67.20s | Rate: 65.48/s
# products: 10  | Time: 66.23s | Rate: 0.15/s
# Memory usage: 48.52 MB (85.20%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 70.93s | Rate: 0.03/s
# customers: 935  | Time: 69.86s | Rate: 13.38/s
# orders: 4500  | Time: 68.43s | Rate: 65.76/s
# products: 10  | Time: 67.46s | Rate: 0.15/s
# Memory usage: 41.11 MB (85.90%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 72.05s | Rate: 0.03/s
# customers: 935  | Time: 70.99s | Rate: 13.17/s
# orders: 4600  | Time: 69.56s | Rate: 66.13/s
# products: 10  | Time: 68.59s | Rate: 0.15/s
# Memory usage: 48.97 MB (85.90%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 73.10s | Rate: 0.03/s
# customers: 935  | Time: 72.03s | Rate: 12.98/s
# orders: 4700  | Time: 70.60s | Rate: 66.57/s
# products: 10  | Time: 69.63s | Rate: 0.14/s
# Memory usage: 49.30 MB (85.40%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 74.70s | Rate: 0.03/s
# customers: 935  | Time: 73.63s | Rate: 12.70/s
# orders: 4800  | Time: 72.20s | Rate: 66.48/s
# products: 10  | Time: 71.23s | Rate: 0.14/s
# Memory usage: 49.42 MB (85.40%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 75.79s | Rate: 0.03/s
# customers: 935  | Time: 74.73s | Rate: 12.51/s
# orders: 4900  | Time: 73.30s | Rate: 66.85/s
# products: 10  | Time: 72.33s | Rate: 0.14/s
# Memory usage: 50.72 MB (85.10%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 77.31s | Rate: 0.03/s
# customers: 935  | Time: 76.24s | Rate: 12.26/s
# orders: 5000  | Time: 74.81s | Rate: 66.83/s
# products: 10  | Time: 73.84s | Rate: 0.14/s
# Memory usage: 65.33 MB (84.50%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 78.55s | Rate: 0.03/s
# customers: 935  | Time: 77.48s | Rate: 12.07/s
# orders: 5100  | Time: 76.05s | Rate: 67.06/s
# products: 10  | Time: 75.08s | Rate: 0.13/s
# Memory usage: 51.98 MB (85.10%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 80.51s | Rate: 0.02/s
# customers: 935  | Time: 79.45s | Rate: 11.77/s
# orders: 5200  | Time: 78.02s | Rate: 66.65/s
# products: 10  | Time: 77.05s | Rate: 0.13/s
# Memory usage: 47.94 MB (85.00%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 81.79s | Rate: 0.02/s
# customers: 935  | Time: 80.72s | Rate: 11.58/s
# orders: 5300  | Time: 79.29s | Rate: 66.84/s
# products: 10  | Time: 78.32s | Rate: 0.13/s
# Memory usage: 48.88 MB (84.90%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 83.85s | Rate: 0.02/s
# customers: 935  | Time: 82.78s | Rate: 11.29/s
# orders: 5500  | Time: 81.35s | Rate: 67.61/s
# products: 10  | Time: 80.38s | Rate: 0.12/s
# Memory usage: 37.31 MB (84.90%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 84.99s | Rate: 0.02/s
# customers: 935  | Time: 83.93s | Rate: 11.14/s
# orders: 5600  | Time: 82.49s | Rate: 67.88/s
# products: 10  | Time: 81.53s | Rate: 0.12/s
# Memory usage: 47.31 MB (84.80%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 86.05s | Rate: 0.02/s
# customers: 935  | Time: 84.98s | Rate: 11.00/s
# orders: 5700  | Time: 83.55s | Rate: 68.22/s
# products: 10  | Time: 82.58s | Rate: 0.12/s
# Memory usage: 48.80 MB (85.00%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 87.20s | Rate: 0.02/s
# customers: 935  | Time: 86.13s | Rate: 10.86/s
# orders: 5800  | Time: 84.70s | Rate: 68.48/s
# products: 10  | Time: 83.73s | Rate: 0.12/s
# Memory usage: 36.55 MB (85.10%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 88.55s | Rate: 0.02/s
# customers: 935  | Time: 87.48s | Rate: 10.69/s
# orders: 5900  | Time: 86.05s | Rate: 68.57/s
# products: 10  | Time: 85.08s | Rate: 0.12/s
# Memory usage: 46.91 MB (85.10%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 89.64s | Rate: 0.02/s
# customers: 935  | Time: 88.57s | Rate: 10.56/s
# orders: 6000  | Time: 87.14s | Rate: 68.86/s
# products: 10  | Time: 86.17s | Rate: 0.12/s
# Memory usage: 37.00 MB (85.70%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 91.57s | Rate: 0.02/s
# customers: 935  | Time: 90.51s | Rate: 10.33/s
# orders: 6200  | Time: 89.07s | Rate: 69.60/s
# products: 10  | Time: 88.10s | Rate: 0.11/s
# Memory usage: 48.12 MB (85.50%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 92.97s | Rate: 0.02/s
# customers: 935  | Time: 91.90s | Rate: 10.17/s
# orders: 6300  | Time: 90.47s | Rate: 69.63/s
# products: 10  | Time: 89.50s | Rate: 0.11/s
# Memory usage: 48.88 MB (84.90%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 94.75s | Rate: 0.02/s
# customers: 935  | Time: 93.69s | Rate: 9.98/s
# orders: 6400  | Time: 92.25s | Rate: 69.37/s
# products: 10  | Time: 91.29s | Rate: 0.11/s
# Memory usage: 40.36 MB (85.50%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 96.35s | Rate: 0.02/s
# customers: 935  | Time: 95.28s | Rate: 9.81/s
# orders: 6500  | Time: 93.85s | Rate: 69.26/s
# products: 10  | Time: 92.88s | Rate: 0.11/s
# Memory usage: 46.91 MB (85.00%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 97.78s | Rate: 0.02/s
# customers: 935  | Time: 96.72s | Rate: 9.67/s
# orders: 6600  | Time: 95.29s | Rate: 69.27/s
# products: 10  | Time: 94.32s | Rate: 0.11/s
# Memory usage: 38.17 MB (84.70%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 99.19s | Rate: 0.02/s
# customers: 935  | Time: 98.12s | Rate: 9.53/s
# orders: 6700  | Time: 96.69s | Rate: 69.29/s
# products: 10  | Time: 95.72s | Rate: 0.10/s
# Memory usage: 47.08 MB (84.20%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 100.55s | Rate: 0.02/s
# customers: 935  | Time: 99.49s | Rate: 9.40/s
# orders: 6800  | Time: 98.06s | Rate: 69.35/s
# products: 10  | Time: 97.09s | Rate: 0.10/s
# Memory usage: 48.42 MB (84.00%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 101.86s | Rate: 0.02/s
# customers: 935  | Time: 100.79s | Rate: 9.28/s
# orders: 6900  | Time: 99.36s | Rate: 69.45/s
# products: 10  | Time: 98.39s | Rate: 0.10/s
# Memory usage: 49.12 MB (84.30%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 103.22s | Rate: 0.02/s
# customers: 935  | Time: 102.15s | Rate: 9.15/s
# orders: 7000  | Time: 100.72s | Rate: 69.50/s
# products: 10  | Time: 99.75s | Rate: 0.10/s
# Memory usage: 49.45 MB (84.60%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 104.65s | Rate: 0.02/s
# customers: 935  | Time: 103.59s | Rate: 9.03/s
# orders: 7100  | Time: 102.16s | Rate: 69.50/s
# products: 10  | Time: 101.19s | Rate: 0.10/s
# Memory usage: 49.31 MB (84.60%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 105.77s | Rate: 0.02/s
# customers: 935  | Time: 104.70s | Rate: 8.93/s
# orders: 7200  | Time: 103.27s | Rate: 69.72/s
# products: 10  | Time: 102.30s | Rate: 0.10/s
# Memory usage: 50.02 MB (84.60%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 106.91s | Rate: 0.02/s
# customers: 935  | Time: 105.84s | Rate: 8.83/s
# orders: 7300  | Time: 104.41s | Rate: 69.91/s
# products: 10  | Time: 103.44s | Rate: 0.10/s
# Memory usage: 49.70 MB (84.50%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 108.05s | Rate: 0.02/s
# customers: 935  | Time: 106.98s | Rate: 8.74/s
# orders: 7400  | Time: 105.55s | Rate: 70.11/s
# products: 10  | Time: 104.58s | Rate: 0.10/s
# Memory usage: 122.20 MB (84.50%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 109.42s | Rate: 0.02/s
# customers: 935  | Time: 108.35s | Rate: 8.63/s
# orders: 7500  | Time: 106.92s | Rate: 70.14/s
# products: 10  | Time: 105.95s | Rate: 0.09/s
# Memory usage: 121.11 MB (84.50%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 110.80s | Rate: 0.02/s
# customers: 935  | Time: 109.73s | Rate: 8.52/s
# orders: 7600  | Time: 108.30s | Rate: 70.18/s
# products: 10  | Time: 107.33s | Rate: 0.09/s
# Memory usage: 95.38 MB (83.80%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 112.24s | Rate: 0.02/s
# customers: 935  | Time: 111.17s | Rate: 8.41/s
# orders: 7700  | Time: 109.74s | Rate: 70.16/s
# products: 10  | Time: 108.77s | Rate: 0.09/s
# Memory usage: 46.75 MB (84.50%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 113.49s | Rate: 0.02/s
# customers: 935  | Time: 112.43s | Rate: 8.32/s
# orders: 7800  | Time: 111.00s | Rate: 70.27/s
# products: 10  | Time: 110.03s | Rate: 0.09/s
# Memory usage: 47.47 MB (84.80%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 114.90s | Rate: 0.02/s
# customers: 935  | Time: 113.84s | Rate: 8.21/s
# orders: 7900  | Time: 112.41s | Rate: 70.28/s
# products: 10  | Time: 111.44s | Rate: 0.09/s
# Memory usage: 48.22 MB (85.00%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 116.02s | Rate: 0.02/s
# customers: 935  | Time: 114.95s | Rate: 8.13/s
# orders: 8000  | Time: 113.52s | Rate: 70.47/s
# products: 10  | Time: 112.55s | Rate: 0.09/s
# Memory usage: 47.73 MB (85.20%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 117.58s | Rate: 0.02/s
# customers: 935  | Time: 116.52s | Rate: 8.02/s
# orders: 8100  | Time: 115.09s | Rate: 70.38/s
# products: 10  | Time: 114.12s | Rate: 0.09/s
# Memory usage: 48.14 MB (85.20%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 118.87s | Rate: 0.02/s
# customers: 935  | Time: 117.80s | Rate: 7.94/s
# orders: 8200  | Time: 116.37s | Rate: 70.47/s
# products: 10  | Time: 115.40s | Rate: 0.09/s
# Memory usage: 48.14 MB (84.70%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 120.40s | Rate: 0.02/s
# customers: 935  | Time: 119.33s | Rate: 7.84/s
# orders: 8300  | Time: 117.90s | Rate: 70.40/s
# products: 10  | Time: 116.93s | Rate: 0.09/s
# Memory usage: 46.20 MB (84.80%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 121.58s | Rate: 0.02/s
# customers: 935  | Time: 120.51s | Rate: 7.76/s
# orders: 8400  | Time: 119.08s | Rate: 70.54/s
# products: 10  | Time: 118.11s | Rate: 0.08/s
# Memory usage: 38.80 MB (84.90%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 122.77s | Rate: 0.02/s
# customers: 935  | Time: 121.71s | Rate: 7.68/s
# orders: 8500  | Time: 120.28s | Rate: 70.67/s
# products: 10  | Time: 119.31s | Rate: 0.08/s
# Memory usage: 47.00 MB (85.10%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 124.82s | Rate: 0.02/s
# customers: 935  | Time: 123.76s | Rate: 7.56/s
# orders: 8700  | Time: 122.33s | Rate: 71.12/s
# products: 10  | Time: 121.36s | Rate: 0.08/s
# Memory usage: 48.03 MB (85.70%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 126.46s | Rate: 0.02/s
# customers: 935  | Time: 125.40s | Rate: 7.46/s
# orders: 8800  | Time: 123.97s | Rate: 70.99/s
# products: 10  | Time: 123.00s | Rate: 0.08/s
# Memory usage: 49.02 MB (85.30%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 127.64s | Rate: 0.02/s
# customers: 935  | Time: 126.57s | Rate: 7.39/s
# orders: 8900  | Time: 125.14s | Rate: 71.12/s
# products: 10  | Time: 124.17s | Rate: 0.08/s
# Memory usage: 48.58 MB (85.20%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 129.12s | Rate: 0.02/s
# customers: 935  | Time: 128.06s | Rate: 7.30/s
# orders: 9000  | Time: 126.63s | Rate: 71.08/s
# products: 10  | Time: 125.66s | Rate: 0.08/s
# Memory usage: 47.09 MB (85.30%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 131.68s | Rate: 0.02/s
# customers: 935  | Time: 130.61s | Rate: 7.16/s
# orders: 9200  | Time: 129.18s | Rate: 71.22/s
# products: 10  | Time: 128.21s | Rate: 0.08/s
# Memory usage: 46.84 MB (85.40%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 132.88s | Rate: 0.02/s
# customers: 935  | Time: 131.81s | Rate: 7.09/s
# orders: 9300  | Time: 130.38s | Rate: 71.33/s
# products: 10  | Time: 129.41s | Rate: 0.08/s
# Memory usage: 49.33 MB (85.40%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 134.04s | Rate: 0.01/s
# customers: 935  | Time: 132.97s | Rate: 7.03/s
# orders: 9400  | Time: 131.54s | Rate: 71.46/s
# products: 10  | Time: 130.57s | Rate: 0.08/s
# Memory usage: 50.06 MB (85.20%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 135.19s | Rate: 0.01/s
# customers: 935  | Time: 134.13s | Rate: 6.97/s
# orders: 9500  | Time: 132.70s | Rate: 71.59/s
# products: 10  | Time: 131.73s | Rate: 0.08/s
# Memory usage: 50.94 MB (85.30%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 136.49s | Rate: 0.01/s
# customers: 935  | Time: 135.43s | Rate: 6.90/s
# orders: 9600  | Time: 133.99s | Rate: 71.64/s
# products: 10  | Time: 133.03s | Rate: 0.08/s
# Memory usage: 51.20 MB (85.30%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 137.57s | Rate: 0.01/s
# customers: 935  | Time: 136.51s | Rate: 6.85/s
# orders: 9700  | Time: 135.08s | Rate: 71.81/s
# products: 10  | Time: 134.11s | Rate: 0.07/s
# Memory usage: 47.28 MB (84.80%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 138.70s | Rate: 0.01/s
# customers: 935  | Time: 137.63s | Rate: 6.79/s
# orders: 9800  | Time: 136.20s | Rate: 71.95/s
# products: 10  | Time: 135.23s | Rate: 0.07/s
# Memory usage: 47.19 MB (84.30%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 140.19s | Rate: 0.01/s
# customers: 935  | Time: 139.13s | Rate: 6.72/s
# orders: 9900  | Time: 137.70s | Rate: 71.90/s
# products: 10  | Time: 136.73s | Rate: 0.07/s
# Memory usage: 47.23 MB (84.80%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 141.75s | Rate: 0.01/s
# customers: 935  | Time: 140.68s | Rate: 6.65/s
# orders: 10000  | Time: 139.25s | Rate: 71.81/s
# products: 10  | Time: 138.28s | Rate: 0.07/s
# Memory usage: 64.55 MB (85.20%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 142.82s | Rate: 0.01/s
# customers: 935  | Time: 141.75s | Rate: 6.60/s
# orders: 10100  | Time: 140.32s | Rate: 71.98/s
# products: 10  | Time: 139.35s | Rate: 0.07/s
# Memory usage: 64.62 MB (85.50%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 144.18s | Rate: 0.01/s
# customers: 935  | Time: 143.11s | Rate: 6.53/s
# orders: 10200  | Time: 141.68s | Rate: 71.99/s
# products: 10  | Time: 140.71s | Rate: 0.07/s
# Memory usage: 62.11 MB (85.50%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 145.51s | Rate: 0.01/s
# customers: 935  | Time: 144.44s | Rate: 6.47/s
# orders: 10300  | Time: 143.01s | Rate: 72.02/s
# products: 10  | Time: 142.04s | Rate: 0.07/s
# Memory usage: 61.70 MB (85.60%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 147.53s | Rate: 0.01/s
# customers: 935  | Time: 146.46s | Rate: 6.38/s
# orders: 10500  | Time: 145.03s | Rate: 72.40/s
# products: 10  | Time: 144.06s | Rate: 0.07/s
# Memory usage: 61.31 MB (85.20%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 149.69s | Rate: 0.01/s
# customers: 935  | Time: 148.63s | Rate: 6.29/s
# orders: 10700  | Time: 147.20s | Rate: 72.69/s
# products: 10  | Time: 146.23s | Rate: 0.07/s
# Memory usage: 45.03 MB (85.50%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 151.21s | Rate: 0.01/s
# customers: 935  | Time: 150.14s | Rate: 6.23/s
# orders: 10800  | Time: 148.71s | Rate: 72.63/s
# products: 10  | Time: 147.74s | Rate: 0.07/s
# Memory usage: 50.03 MB (85.60%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 152.28s | Rate: 0.01/s
# customers: 935  | Time: 151.22s | Rate: 6.18/s
# orders: 10900  | Time: 149.79s | Rate: 72.77/s
# products: 10  | Time: 148.82s | Rate: 0.07/s
# Memory usage: 51.00 MB (85.60%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 153.39s | Rate: 0.01/s
# customers: 935  | Time: 152.33s | Rate: 6.14/s
# orders: 11000  | Time: 150.90s | Rate: 72.90/s
# products: 10  | Time: 149.93s | Rate: 0.07/s
# Memory usage: 51.69 MB (85.20%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 154.72s | Rate: 0.01/s
# customers: 935  | Time: 153.65s | Rate: 6.09/s
# orders: 11100  | Time: 152.22s | Rate: 72.92/s
# products: 10  | Time: 151.25s | Rate: 0.07/s
# Memory usage: 51.77 MB (85.30%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 155.82s | Rate: 0.01/s
# customers: 935  | Time: 154.76s | Rate: 6.04/s
# orders: 11200  | Time: 153.33s | Rate: 73.05/s
# products: 10  | Time: 152.36s | Rate: 0.07/s
# Memory usage: 39.09 MB (84.90%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 156.90s | Rate: 0.01/s
# customers: 935  | Time: 155.84s | Rate: 6.00/s
# orders: 11300  | Time: 154.41s | Rate: 73.18/s
# products: 10  | Time: 153.44s | Rate: 0.07/s
# Memory usage: 47.42 MB (85.00%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 159.09s | Rate: 0.01/s
# customers: 935  | Time: 158.02s | Rate: 5.92/s
# orders: 11500  | Time: 156.59s | Rate: 73.44/s
# products: 10  | Time: 155.62s | Rate: 0.06/s
# Memory usage: 49.33 MB (85.00%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 160.37s | Rate: 0.01/s
# customers: 935  | Time: 159.30s | Rate: 5.87/s
# orders: 11600  | Time: 157.87s | Rate: 73.48/s
# products: 10  | Time: 156.90s | Rate: 0.06/s
# Memory usage: 50.00 MB (85.10%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 161.77s | Rate: 0.01/s
# customers: 935  | Time: 160.71s | Rate: 5.82/s
# orders: 11700  | Time: 159.28s | Rate: 73.46/s
# products: 10  | Time: 158.31s | Rate: 0.06/s
# Memory usage: 49.55 MB (85.30%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 163.11s | Rate: 0.01/s
# customers: 935  | Time: 162.05s | Rate: 5.77/s
# orders: 11800  | Time: 160.62s | Rate: 73.47/s
# products: 10  | Time: 159.65s | Rate: 0.06/s
# Memory usage: 121.95 MB (85.30%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 164.22s | Rate: 0.01/s
# customers: 935  | Time: 163.15s | Rate: 5.73/s
# orders: 11900  | Time: 161.72s | Rate: 73.58/s
# products: 10  | Time: 160.75s | Rate: 0.06/s
# Memory usage: 121.50 MB (85.60%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 166.34s | Rate: 0.01/s
# customers: 935  | Time: 165.28s | Rate: 5.66/s
# orders: 12100  | Time: 163.85s | Rate: 73.85/s
# products: 10  | Time: 162.88s | Rate: 0.06/s
# Memory usage: 120.91 MB (85.70%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 168.74s | Rate: 0.01/s
# customers: 935  | Time: 167.67s | Rate: 5.58/s
# orders: 12300  | Time: 166.24s | Rate: 73.99/s
# products: 10  | Time: 165.27s | Rate: 0.06/s
# Memory usage: 45.80 MB (85.50%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 170.12s | Rate: 0.01/s
# customers: 935  | Time: 169.06s | Rate: 5.53/s
# orders: 12400  | Time: 167.62s | Rate: 73.97/s
# products: 10  | Time: 166.65s | Rate: 0.06/s
# Memory usage: 36.25 MB (84.90%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 171.21s | Rate: 0.01/s
# customers: 935  | Time: 170.15s | Rate: 5.50/s
# orders: 12500  | Time: 168.72s | Rate: 74.09/s
# products: 10  | Time: 167.75s | Rate: 0.06/s
# Memory usage: 46.28 MB (85.30%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 172.50s | Rate: 0.01/s
# customers: 935  | Time: 171.43s | Rate: 5.45/s
# orders: 12600  | Time: 170.00s | Rate: 74.12/s
# products: 10  | Time: 169.03s | Rate: 0.06/s
# Memory usage: 35.92 MB (85.20%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 173.63s | Rate: 0.01/s
# customers: 935  | Time: 172.57s | Rate: 5.42/s
# orders: 12700  | Time: 171.14s | Rate: 74.21/s
# products: 10  | Time: 170.17s | Rate: 0.06/s
# Memory usage: 37.47 MB (85.40%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 175.13s | Rate: 0.01/s
# customers: 935  | Time: 174.06s | Rate: 5.37/s
# orders: 12800  | Time: 172.63s | Rate: 74.15/s
# products: 10  | Time: 171.66s | Rate: 0.06/s
# Memory usage: 44.91 MB (85.80%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 176.43s | Rate: 0.01/s
# customers: 935  | Time: 175.37s | Rate: 5.33/s
# orders: 12900  | Time: 173.93s | Rate: 74.17/s
# products: 10  | Time: 172.97s | Rate: 0.06/s
# Memory usage: 45.91 MB (85.60%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 178.13s | Rate: 0.01/s
# customers: 935  | Time: 177.07s | Rate: 5.28/s
# orders: 13100  | Time: 175.64s | Rate: 74.59/s
# products: 10  | Time: 174.67s | Rate: 0.06/s
# Memory usage: 44.53 MB (86.50%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 179.28s | Rate: 0.01/s
# customers: 935  | Time: 178.21s | Rate: 5.25/s
# orders: 13200  | Time: 176.78s | Rate: 74.67/s
# products: 10  | Time: 175.81s | Rate: 0.06/s
# Memory usage: 47.09 MB (87.90%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 181.62s | Rate: 0.01/s
# customers: 935  | Time: 180.55s | Rate: 5.18/s
# orders: 13400  | Time: 179.12s | Rate: 74.81/s
# products: 10  | Time: 178.15s | Rate: 0.06/s
# Memory usage: 37.42 MB (88.70%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 183.00s | Rate: 0.01/s
# customers: 935  | Time: 181.93s | Rate: 5.14/s
# orders: 13500  | Time: 180.50s | Rate: 74.79/s
# products: 10  | Time: 179.53s | Rate: 0.06/s
# Memory usage: 38.38 MB (88.50%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 184.18s | Rate: 0.01/s
# customers: 935  | Time: 183.11s | Rate: 5.11/s
# orders: 13600  | Time: 181.68s | Rate: 74.86/s
# products: 10  | Time: 180.71s | Rate: 0.06/s
# Memory usage: 46.25 MB (88.80%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 185.28s | Rate: 0.01/s
# customers: 935  | Time: 184.21s | Rate: 5.08/s
# orders: 13700  | Time: 182.78s | Rate: 74.95/s
# products: 10  | Time: 181.81s | Rate: 0.06/s
# Memory usage: 35.67 MB (88.30%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 186.40s | Rate: 0.01/s
# customers: 935  | Time: 185.33s | Rate: 5.05/s
# orders: 13800  | Time: 183.90s | Rate: 75.04/s
# products: 10  | Time: 182.93s | Rate: 0.05/s
# Memory usage: 36.95 MB (89.30%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 188.07s | Rate: 0.01/s
# customers: 935  | Time: 187.00s | Rate: 5.00/s
# orders: 13900  | Time: 185.57s | Rate: 74.90/s
# products: 10  | Time: 184.60s | Rate: 0.05/s
# Memory usage: 35.42 MB (89.70%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 189.29s | Rate: 0.01/s
# customers: 935  | Time: 188.22s | Rate: 4.97/s
# orders: 14000  | Time: 186.79s | Rate: 74.95/s
# products: 10  | Time: 185.82s | Rate: 0.05/s
# Memory usage: 45.84 MB (89.70%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 190.58s | Rate: 0.01/s
# customers: 935  | Time: 189.51s | Rate: 4.93/s
# orders: 14100  | Time: 188.08s | Rate: 74.97/s
# products: 10  | Time: 187.11s | Rate: 0.05/s
# Memory usage: 46.20 MB (89.70%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 192.06s | Rate: 0.01/s
# customers: 935  | Time: 191.00s | Rate: 4.90/s
# orders: 14200  | Time: 189.57s | Rate: 74.91/s
# products: 10  | Time: 188.60s | Rate: 0.05/s
# Memory usage: 45.27 MB (83.10%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 193.35s | Rate: 0.01/s
# customers: 935  | Time: 192.28s | Rate: 4.86/s
# orders: 14300  | Time: 190.85s | Rate: 74.93/s
# products: 10  | Time: 189.88s | Rate: 0.05/s
# Memory usage: 46.08 MB (81.10%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 194.57s | Rate: 0.01/s
# customers: 935  | Time: 193.50s | Rate: 4.83/s
# orders: 14400  | Time: 192.07s | Rate: 74.97/s
# products: 10  | Time: 191.10s | Rate: 0.05/s
# Memory usage: 47.83 MB (78.60%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 196.21s | Rate: 0.01/s
# customers: 935  | Time: 195.14s | Rate: 4.79/s
# orders: 14500  | Time: 193.71s | Rate: 74.85/s
# products: 10  | Time: 192.74s | Rate: 0.05/s
# Memory usage: 48.55 MB (76.60%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 197.80s | Rate: 0.01/s
# customers: 935  | Time: 196.73s | Rate: 4.75/s
# orders: 14600  | Time: 195.30s | Rate: 74.76/s
# products: 10  | Time: 194.33s | Rate: 0.05/s
# Memory usage: 49.30 MB (76.20%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 199.38s | Rate: 0.01/s
# customers: 935  | Time: 198.31s | Rate: 4.71/s
# orders: 14700  | Time: 196.88s | Rate: 74.66/s
# products: 10  | Time: 195.91s | Rate: 0.05/s
# Memory usage: 49.78 MB (76.30%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 200.46s | Rate: 0.01/s
# customers: 935  | Time: 199.39s | Rate: 4.69/s
# orders: 14800  | Time: 197.96s | Rate: 74.76/s
# products: 10  | Time: 196.99s | Rate: 0.05/s
# Memory usage: 50.48 MB (76.20%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 202.06s | Rate: 0.01/s
# customers: 935  | Time: 200.99s | Rate: 4.65/s
# orders: 14900  | Time: 199.56s | Rate: 74.66/s
# products: 10  | Time: 198.59s | Rate: 0.05/s
# Memory usage: 51.02 MB (75.40%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 203.46s | Rate: 0.01/s
# customers: 935  | Time: 202.39s | Rate: 4.62/s
# orders: 15000  | Time: 200.96s | Rate: 74.64/s
# products: 10  | Time: 199.99s | Rate: 0.05/s
# Memory usage: 65.47 MB (75.90%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 204.56s | Rate: 0.01/s
# customers: 935  | Time: 203.50s | Rate: 4.59/s
# orders: 15100  | Time: 202.06s | Rate: 74.73/s
# products: 10  | Time: 201.09s | Rate: 0.05/s
# Memory usage: 65.45 MB (75.70%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 205.93s | Rate: 0.01/s
# customers: 935  | Time: 204.86s | Rate: 4.56/s
# orders: 15200  | Time: 203.43s | Rate: 74.72/s
# products: 10  | Time: 202.46s | Rate: 0.05/s
# Memory usage: 65.31 MB (75.70%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 207.26s | Rate: 0.01/s
# customers: 935  | Time: 206.20s | Rate: 4.53/s
# orders: 15300  | Time: 204.76s | Rate: 74.72/s
# products: 10  | Time: 203.80s | Rate: 0.05/s
# Memory usage: 62.28 MB (76.00%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 208.76s | Rate: 0.01/s
# customers: 935  | Time: 207.70s | Rate: 4.50/s
# orders: 15400  | Time: 206.26s | Rate: 74.66/s
# products: 10  | Time: 205.30s | Rate: 0.05/s
# Memory usage: 61.92 MB (76.30%) | CPU usage: 0.00%
#
# ...
# customers: 935  | Time: 654.12s | Rate: 1.43/s
# orders: 57200  | Time: 652.69s | Rate: 87.64/s
# products: 10  | Time: 651.72s | Rate: 0.02/s
# Memory usage: 55.23 MB (84.50%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 656.59s | Rate: 0.00/s
# customers: 935  | Time: 655.52s | Rate: 1.43/s
# orders: 57300  | Time: 654.09s | Rate: 87.60/s
# products: 10  | Time: 653.12s | Rate: 0.02/s
# Memory usage: 54.53 MB (83.90%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 658.33s | Rate: 0.00/s
# customers: 935  | Time: 657.26s | Rate: 1.42/s
# orders: 57500  | Time: 655.83s | Rate: 87.67/s
# products: 10  | Time: 654.86s | Rate: 0.02/s
# Memory usage: 54.91 MB (83.50%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 659.65s | Rate: 0.00/s
# customers: 935  | Time: 658.59s | Rate: 1.42/s
# orders: 57600  | Time: 657.16s | Rate: 87.65/s
# products: 10  | Time: 656.19s | Rate: 0.02/s
# Memory usage: 50.80 MB (83.30%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 661.40s | Rate: 0.00/s
# customers: 935  | Time: 660.33s | Rate: 1.42/s
# orders: 57800  | Time: 658.90s | Rate: 87.72/s
# products: 10  | Time: 657.93s | Rate: 0.02/s
# Memory usage: 51.19 MB (84.00%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 663.58s | Rate: 0.00/s
# customers: 935  | Time: 662.52s | Rate: 1.41/s
# orders: 58000  | Time: 661.09s | Rate: 87.73/s
# products: 10  | Time: 660.12s | Rate: 0.02/s
# Memory usage: 48.52 MB (84.00%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 664.69s | Rate: 0.00/s
# customers: 935  | Time: 663.63s | Rate: 1.41/s
# orders: 58100  | Time: 662.19s | Rate: 87.74/s
# products: 10  | Time: 661.22s | Rate: 0.02/s
# Memory usage: 48.61 MB (84.40%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 666.31s | Rate: 0.00/s
# customers: 935  | Time: 665.25s | Rate: 1.41/s
# orders: 58200  | Time: 663.82s | Rate: 87.67/s
# products: 10  | Time: 662.85s | Rate: 0.02/s
# Memory usage: 48.84 MB (85.10%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 667.83s | Rate: 0.00/s
# customers: 935  | Time: 666.77s | Rate: 1.40/s
# orders: 58300  | Time: 665.34s | Rate: 87.62/s
# products: 10  | Time: 664.37s | Rate: 0.02/s
# Memory usage: 47.23 MB (84.90%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 669.32s | Rate: 0.00/s
# customers: 935  | Time: 668.26s | Rate: 1.40/s
# orders: 58400  | Time: 666.83s | Rate: 87.58/s
# products: 10  | Time: 665.86s | Rate: 0.02/s
# Memory usage: 48.44 MB (84.70%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 670.99s | Rate: 0.00/s
# customers: 935  | Time: 669.92s | Rate: 1.40/s
# orders: 58600  | Time: 668.49s | Rate: 87.66/s
# products: 10  | Time: 667.52s | Rate: 0.01/s
# Memory usage: 49.78 MB (84.30%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 672.10s | Rate: 0.00/s
# customers: 935  | Time: 671.03s | Rate: 1.39/s
# orders: 58700  | Time: 669.60s | Rate: 87.66/s
# products: 10  | Time: 668.63s | Rate: 0.01/s
# Memory usage: 50.48 MB (84.50%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 673.38s | Rate: 0.00/s
# customers: 935  | Time: 672.31s | Rate: 1.39/s
# orders: 58800  | Time: 670.88s | Rate: 87.65/s
# products: 10  | Time: 669.91s | Rate: 0.01/s
# Memory usage: 51.97 MB (84.40%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 675.35s | Rate: 0.00/s
# customers: 935  | Time: 674.29s | Rate: 1.39/s
# orders: 59000  | Time: 672.85s | Rate: 87.69/s
# products: 10  | Time: 671.89s | Rate: 0.01/s
# Memory usage: 50.19 MB (85.20%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 676.67s | Rate: 0.00/s
# customers: 935  | Time: 675.60s | Rate: 1.38/s
# orders: 59100  | Time: 674.17s | Rate: 87.66/s
# products: 10  | Time: 673.20s | Rate: 0.01/s
# Memory usage: 52.20 MB (84.50%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 677.88s | Rate: 0.00/s
# customers: 935  | Time: 676.82s | Rate: 1.38/s
# orders: 59200  | Time: 675.39s | Rate: 87.65/s
# products: 10  | Time: 674.42s | Rate: 0.01/s
# Memory usage: 52.52 MB (84.30%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 679.52s | Rate: 0.00/s
# customers: 935  | Time: 678.45s | Rate: 1.38/s
# orders: 59400  | Time: 677.02s | Rate: 87.74/s
# products: 10  | Time: 676.05s | Rate: 0.01/s
# Memory usage: 51.14 MB (84.30%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 680.77s | Rate: 0.00/s
# customers: 935  | Time: 679.70s | Rate: 1.38/s
# orders: 59500  | Time: 678.27s | Rate: 87.72/s
# products: 10  | Time: 677.30s | Rate: 0.01/s
# Memory usage: 48.50 MB (84.20%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 682.18s | Rate: 0.00/s
# customers: 935  | Time: 681.12s | Rate: 1.37/s
# orders: 59600  | Time: 679.69s | Rate: 87.69/s
# products: 10  | Time: 678.72s | Rate: 0.01/s
# Memory usage: 49.33 MB (84.90%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 684.19s | Rate: 0.00/s
# customers: 935  | Time: 683.12s | Rate: 1.37/s
# orders: 59800  | Time: 681.69s | Rate: 87.72/s
# products: 10  | Time: 680.72s | Rate: 0.01/s
# Memory usage: 46.89 MB (85.10%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 686.68s | Rate: 0.00/s
# customers: 935  | Time: 685.62s | Rate: 1.36/s
# orders: 60000  | Time: 684.19s | Rate: 87.70/s
# products: 10  | Time: 683.22s | Rate: 0.01/s
# Memory usage: 64.28 MB (84.80%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 688.44s | Rate: 0.00/s
# customers: 935  | Time: 687.37s | Rate: 1.36/s
# orders: 60200  | Time: 685.94s | Rate: 87.76/s
# products: 10  | Time: 684.97s | Rate: 0.01/s
# Memory usage: 62.84 MB (84.90%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 689.71s | Rate: 0.00/s
# customers: 935  | Time: 688.64s | Rate: 1.36/s
# orders: 60300  | Time: 687.21s | Rate: 87.75/s
# products: 10  | Time: 686.24s | Rate: 0.01/s
# Memory usage: 125.67 MB (83.50%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 690.96s | Rate: 0.00/s
# customers: 935  | Time: 689.90s | Rate: 1.36/s
# orders: 60400  | Time: 688.47s | Rate: 87.73/s
# products: 10  | Time: 687.50s | Rate: 0.01/s
# Memory usage: 122.83 MB (83.20%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 691.99s | Rate: 0.00/s
# customers: 935  | Time: 690.93s | Rate: 1.35/s
# orders: 60500  | Time: 689.50s | Rate: 87.75/s
# products: 10  | Time: 688.53s | Rate: 0.01/s
# Memory usage: 123.02 MB (84.00%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 693.97s | Rate: 0.00/s
# customers: 935  | Time: 692.90s | Rate: 1.35/s
# orders: 60700  | Time: 691.47s | Rate: 87.78/s
# products: 10  | Time: 690.50s | Rate: 0.01/s
# Memory usage: 122.98 MB (83.70%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 695.69s | Rate: 0.00/s
# customers: 935  | Time: 694.63s | Rate: 1.35/s
# orders: 60900  | Time: 693.20s | Rate: 87.85/s
# products: 10  | Time: 692.23s | Rate: 0.01/s
# Memory usage: 48.61 MB (84.80%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 697.41s | Rate: 0.00/s
# customers: 935  | Time: 696.35s | Rate: 1.34/s
# orders: 61100  | Time: 694.92s | Rate: 87.92/s
# products: 10  | Time: 693.95s | Rate: 0.01/s
# Memory usage: 50.41 MB (84.30%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 698.57s | Rate: 0.00/s
# customers: 935  | Time: 697.51s | Rate: 1.34/s
# orders: 61200  | Time: 696.08s | Rate: 87.92/s
# products: 10  | Time: 695.11s | Rate: 0.01/s
# Memory usage: 50.86 MB (84.20%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 700.01s | Rate: 0.00/s
# customers: 935  | Time: 698.95s | Rate: 1.34/s
# orders: 61300  | Time: 697.52s | Rate: 87.88/s
# products: 10  | Time: 696.55s | Rate: 0.01/s
# Memory usage: 48.94 MB (84.30%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 702.55s | Rate: 0.00/s
# customers: 935  | Time: 701.49s | Rate: 1.33/s
# orders: 61500  | Time: 700.06s | Rate: 87.85/s
# products: 10  | Time: 699.09s | Rate: 0.01/s
# Memory usage: 49.00 MB (83.80%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 703.56s | Rate: 0.00/s
# customers: 935  | Time: 702.50s | Rate: 1.33/s
# orders: 61600  | Time: 701.07s | Rate: 87.87/s
# products: 10  | Time: 700.10s | Rate: 0.01/s
# Memory usage: 49.45 MB (83.60%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 705.20s | Rate: 0.00/s
# customers: 935  | Time: 704.14s | Rate: 1.33/s
# orders: 61800  | Time: 702.71s | Rate: 87.95/s
# products: 10  | Time: 701.74s | Rate: 0.01/s
# Memory usage: 43.00 MB (84.70%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 2/3 (66.7%) | Time: 706.78s | Rate: 0.00/s
# customers: 935  | Time: 705.72s | Rate: 1.32/s
# orders: 61948  | Time: 704.28s | Rate: 87.96/s
# products: 10  | Time: 703.31s | Rate: 0.01/s
# Memory usage: 47.05 MB (85.00%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 3/3 (100.0%) | Time: 707.45s | Rate: 0.00/s
# customers: 935  | Time: 706.39s | Rate: 1.32/s
# orders: 61948  | Time: 704.96s | Rate: 87.87/s
# products: 10  | Time: 703.99s | Rate: 0.01/s
# Memory usage: 60.28 MB (84.60%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 0/1 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Memory usage: 66.81 MB (84.60%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 0/1 (0.0%) | Time: 0.00s | Rate: 0.00/s
# _dlt_pipeline_state: 1  | Time: 0.00s | Rate: 1048576.00/s
# Memory usage: 67.19 MB (84.60%) | CPU usage: 0.00%
#
# ----------------------------- Extract jaffle_shop ------------------------------
# Resources: 1/1 (100.0%) | Time: 0.02s | Rate: 61.02/s
# _dlt_pipeline_state: 1  | Time: 0.01s | Rate: 69.62/s
# Memory usage: 67.70 MB (84.60%) | CPU usage: 0.00%
# ExtractInfo(pipeline=<dlt.pipeline.pipeline.Pipeline object at 0x12174a110>, metrics={'1748263925.1556349': [{'started_at': DateTime(2025, 5, 26, 12, 52, 5, 159860, tzinfo=Timezone('UTC')), 'finished_at': DateTime(2025, 5, 26, 13, 3, 52, 614968, tzinfo=Timezone('UTC')), 'schema_name': 'jaffle_shop', 'job_metrics': {'customers.f5fe9da844.typed-jsonl': DataWriterMetrics(file_path='/Users/redperiabras/.dlt/pipelines/dlt_ipykernel_launcher/normalize/627c2760bdd3c33a/1748263925.1556349/new_jobs/customers.f5fe9da844.0.typed-jsonl', items_count=935, file_size=64816, created=1748263926.227572, last_modified=1748263950.141396), 'orders.cd787b0610.typed-jsonl': DataWriterMetrics(file_path='/Users/redperiabras/.dlt/pipelines/dlt_ipykernel_launcher/normalize/627c2760bdd3c33a/1748263925.1556349/new_jobs/orders.cd787b0610.0.typed-jsonl', items_count=61948, file_size=25523121, created=1748263927.658583, last_modified=1748264632.548816), 'products.a9e957e93e.typed-jsonl': DataWriterMetrics(file_path='/Users/redperiabras/.dlt/pipelines/dlt_ipykernel_launcher/normalize/627c2760bdd3c33a/1748263925.1556349/new_jobs/products.a9e957e93e.0.typed-jsonl', items_count=10, file_size=1416, created=1748263928.627976, last_modified=1748263931.6875)}, 'table_metrics': {'customers': DataWriterMetrics(file_path='', items_count=935, file_size=64816, created=1748263926.227572, last_modified=1748263950.141396), 'orders': DataWriterMetrics(file_path='', items_count=61948, file_size=25523121, created=1748263927.658583, last_modified=1748264632.548816), 'products': DataWriterMetrics(file_path='', items_count=10, file_size=1416, created=1748263928.627976, last_modified=1748263931.6875)}, 'resource_metrics': {'customers': DataWriterMetrics(file_path='', items_count=935, file_size=64816, created=1748263926.227572, last_modified=1748263950.141396), 'orders': DataWriterMetrics(file_path='', items_count=61948, file_size=25523121, created=1748263927.658583, last_modified=1748264632.548816), 'products': DataWriterMetrics(file_path='', items_count=10, file_size=1416, created=1748263928.627976, last_modified=1748263931.6875)}, 'dag': [('customers', 'customers'), ('orders', 'orders'), ('products', 'products')], 'hints': {'customers': {'write_disposition': 'append'}, 'orders': {'write_disposition': 'append'}, 'products': {'write_disposition': 'append'}}}, {'started_at': DateTime(2025, 5, 26, 13, 3, 52, 633098, tzinfo=Timezone('UTC')), 'finished_at': DateTime(2025, 5, 26, 13, 3, 52, 649857, tzinfo=Timezone('UTC')), 'schema_name': 'jaffle_shop', 'job_metrics': {'_dlt_pipeline_state.232894b56d.typed-jsonl': DataWriterMetrics(file_path='/Users/redperiabras/.dlt/pipelines/dlt_ipykernel_launcher/normalize/627c2760bdd3c33a/1748263925.1556349/new_jobs/_dlt_pipeline_state.232894b56d.0.typed-jsonl', items_count=1, file_size=532, created=1748264632.635502, last_modified=1748264632.6355069)}, 'table_metrics': {'_dlt_pipeline_state': DataWriterMetrics(file_path='', items_count=1, file_size=532, created=1748264632.635502, last_modified=1748264632.6355069)}, 'resource_metrics': {'_dlt_pipeline_state': DataWriterMetrics(file_path='', items_count=1, file_size=532, created=1748264632.635502, last_modified=1748264632.6355069)}, 'dag': [('_dlt_pipeline_state', '_dlt_pipeline_state')], 'hints': {'_dlt_pipeline_state': {'columns': 'version:\n  name: version\n  data_type: bigint\n  nullable: false\nengine_version:\n  name: engine_version\n  data_type: bigint\n  nullable: false\npipeline_name:\n  name: pipeline_name\n  data_type: text\n  nullable: false\nstate:\n  name: state\n  data_type: text\n  nullable: false\ncreated_at:\n  name: created_at\n  data_type: timestamp\n  nullable: false\nversion_hash:\n  name: version_hash\n  data_type: text\n  nullable: true\n_dlt_load_id:\n  name: _dlt_load_id\n  data_type: text\n  nullable: false\n', 'write_disposition': 'append', 'file_format': 'preferred', 'original_columns': 'dict'}}}]}, extract_data_info=[{'name': 'jaffle_shop', 'data_type': 'source'}], loads ...

# %%
# %%timeit

pipeline.normalize()
# Out:
# ----------------- Normalize jaffle_shop in 1748263925.1556349 ------------------
# Files: 0/4 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Memory usage: 77.28 MB (84.70%) | CPU usage: 0.00%
#
# ----------------- Normalize jaffle_shop in 1748263925.1556349 ------------------
# Files: 0/4 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Items: 0  | Time: 0.00s | Rate: 0.00/s
# Memory usage: 77.28 MB (84.70%) | CPU usage: 0.00%
#
# ----------------- Normalize jaffle_shop in 1748263925.1556349 ------------------
# Files: 5/4 (125.0%) | Time: 5.48s | Rate: 0.91/s
# Items: 0  | Time: 5.48s | Rate: 0.00/s
# Memory usage: 196.34 MB (84.00%) | CPU usage: 0.00%
#
# ----------------- Normalize jaffle_shop in 1748263925.1556349 ------------------
# Files: 5/4 (125.0%) | Time: 5.49s | Rate: 0.91/s
# Items: 153794  | Time: 5.49s | Rate: 27997.67/s
# Memory usage: 201.72 MB (84.00%) | CPU usage: 0.00%
#
# 8.14 ms ± 1.41 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit

load_info = pipeline.load()
# Out:
# 8.26 ms ± 145 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
print(pipeline.last_trace)
# Out:
# Run started at 2025-05-26 12:52:05.142543+00:00 and COMPLETED in 34 minutes and 4.45 seconds with 100 steps.
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
#
# Step load COMPLETED in 0.01 seconds.
# Pipeline dlt_ipykernel_launcher load step completed in ---
# 0 load package(s) were loaded to destination duckdb and into dataset None
# The duckdb destination used duckdb:////Users/redperiabras/Developer/dlt-advanced/dlt_ipykernel_launcher.duckdb location to store data
